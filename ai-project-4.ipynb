# %%
# import google drive
from google.colab import drive

# mount google drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# unzip data.zip
# !unzip "/content/drive/MyDrive/studies/ai-project/data.zip" -d /content/data_dir
# Out:
# Archive:  /content/drive/MyDrive/studies/ai-project/data.zip
#    creating: /content/data_dir/nucleus/
#   inflating: /content/data_dir/nucleus/48.png
#   inflating: /content/data_dir/nucleus/47.png
#   inflating: /content/data_dir/nucleus/46.png
#   inflating: /content/data_dir/nucleus/45.png
#   inflating: /content/data_dir/nucleus/44.png
#   inflating: /content/data_dir/nucleus/43.png
#   inflating: /content/data_dir/nucleus/42.png
#   inflating: /content/data_dir/nucleus/41.png
#   inflating: /content/data_dir/nucleus/40.png
#   inflating: /content/data_dir/nucleus/4.png
#   inflating: /content/data_dir/nucleus/39.png
#   inflating: /content/data_dir/nucleus/38.png
#   inflating: /content/data_dir/nucleus/37.png
#   inflating: /content/data_dir/nucleus/36.png
#   inflating: /content/data_dir/nucleus/35.png
#   inflating: /content/data_dir/nucleus/34.png
#   inflating: /content/data_dir/nucleus/33.png
#   inflating: /content/data_dir/nucleus/32.png
#   inflating: /content/data_dir/nucleus/31.png
#   inflating: /content/data_dir/nucleus/30.png
#   inflating: /content/data_dir/nucleus/3.png
#   inflating: /content/data_dir/nucleus/29.png
#   inflating: /content/data_dir/nucleus/28.png
#   inflating: /content/data_dir/nucleus/27.png
#   inflating: /content/data_dir/nucleus/26.png
#   inflating: /content/data_dir/nucleus/25.png
#   inflating: /content/data_dir/nucleus/24.png
#   inflating: /content/data_dir/nucleus/23.png
#   inflating: /content/data_dir/nucleus/22.png
#   inflating: /content/data_dir/nucleus/20.png
#   inflating: /content/data_dir/nucleus/2.png
#   inflating: /content/data_dir/nucleus/192.png
#   inflating: /content/data_dir/nucleus/191.png
#   inflating: /content/data_dir/nucleus/190.png
#   inflating: /content/data_dir/nucleus/19.png
#   inflating: /content/data_dir/nucleus/189.png
#   inflating: /content/data_dir/nucleus/188.png
#   inflating: /content/data_dir/nucleus/187.png
#   inflating: /content/data_dir/nucleus/186.png
#   inflating: /content/data_dir/nucleus/185.png
#   inflating: /content/data_dir/nucleus/184.png
#   inflating: /content/data_dir/nucleus/183.png
#   inflating: /content/data_dir/nucleus/182.png
#   inflating: /content/data_dir/nucleus/181.png
#   inflating: /content/data_dir/nucleus/180.png
#   inflating: /content/data_dir/nucleus/18.png
#   inflating: /content/data_dir/nucleus/179.png
#   inflating: /content/data_dir/nucleus/178.png
#   inflating: /content/data_dir/nucleus/177.png
#   inflating: /content/data_dir/nucleus/176.png
#   inflating: /content/data_dir/nucleus/175.png
#   inflating: /content/data_dir/nucleus/174.png
#   inflating: /content/data_dir/nucleus/173.png
#   inflating: /content/data_dir/nucleus/172.png
#   inflating: /content/data_dir/nucleus/171.png
#   inflating: /content/data_dir/nucleus/170.png
#   inflating: /content/data_dir/nucleus/17.png
#   inflating: /content/data_dir/nucleus/169.png
#   inflating: /content/data_dir/nucleus/168.png
#   inflating: /content/data_dir/nucleus/167.png
#   inflating: /content/data_dir/nucleus/166.png
#   inflating: /content/data_dir/nucleus/165.png
#   inflating: /content/data_dir/nucleus_images_blue/104.png
#   inflating: /content/data_dir/nucleus_images_blue/103.png
#   inflating: /content/data_dir/nucleus_images_blue/102.png
#   inflating: /content/data_dir/nucleus_images_blue/100.png
#   inflating: /content/data_dir/nucleus_images_blue/10.tif
#   inflating: /content/data_dir/nucleus_images_blue/1.tif
#   inflating: /content/data_dir/nucleus_images_blue/0.jpg
#   inflating: /content/data_dir/nucleus_images_blue/99.png
#   inflating: /content/data_dir/nucleus_images_blue/98.png
#   inflating: /content/data_dir/nucleus_images_blue/97.png
#   inflating: /content/data_dir/nucleus_images_blue/96.png
#   inflating: /content/data_dir/nucleus_images_blue/95.png
#   inflating: /content/data_dir/nucleus_images_blue/94.png
#   inflating: /content/data_dir/nucleus_images_blue/93.png
#   inflating: /content/data_dir/nucleus_images_blue/92.png
#   inflating: /content/data_dir/nucleus_images_blue/91.png
#   inflating: /content/data_dir/nucleus_images_blue/90.png
#   inflating: /content/data_dir/nucleus_images_blue/9.tif
#   inflating: /content/data_dir/nucleus_images_blue/89.png
#   inflating: /content/data_dir/nucleus_images_blue/88.png
#   inflating: /content/data_dir/nucleus_images_blue/87.png
#   inflating: /content/data_dir/nucleus_images_blue/86.png
#   inflating: /content/data_dir/nucleus_images_blue/85.png
#   inflating: /content/data_dir/nucleus_images_blue/84.png
#   inflating: /content/data_dir/nucleus_images_blue/83.png
#   inflating: /content/data_dir/nucleus_images_blue/82.png
#   inflating: /content/data_dir/nucleus_images_blue/81.png
#   inflating: /content/data_dir/nucleus_images_blue/80.png
#   inflating: /content/data_dir/nucleus_images_blue/8.tif
#   inflating: /content/data_dir/nucleus_images_blue/79.png
#   inflating: /content/data_dir/nucleus_images_blue/78.png
#   inflating: /content/data_dir/nucleus_images_blue/76.tif
#   inflating: /content/data_dir/nucleus_images_blue/75.png
#   inflating: /content/data_dir/nucleus_images_blue/74.png
#   inflating: /content/data_dir/nucleus_images_blue/73.png
#   inflating: /content/data_dir/nucleus_images_blue/72.png
#   inflating: /content/data_dir/nucleus_images_blue/71.png
#   inflating: /content/data_dir/nucleus_images_blue/70.png
#   inflating: /content/data_dir/nucleus_images_blue/7.jpg
#   inflating: /content/data_dir/nucleus_images_blue/69.png
#   inflating: /content/data_dir/nucleus_images_blue/68.png
#   inflating: /content/data_dir/nucleus_images_blue/67.png
#   inflating: /content/data_dir/nucleus_images_blue/66.png
#   inflating: /content/data_dir/nucleus_images_blue/65.png
#   inflating: /content/data_dir/nucleus_images_blue/64.png
#   inflating: /content/data_dir/nucleus_images_blue/63.png
#   inflating: /content/data_dir/nucleus_images_blue/62.png
#   inflating: /content/data_dir/nucleus_images_blue/61.png
#   inflating: /content/data_dir/nucleus_images_blue/60.png
#   inflating: /content/data_dir/nucleus_images_blue/6.tif
#   inflating: /content/data_dir/nucleus_images_blue/59.png
#   inflating: /content/data_dir/nucleus_images_blue/57.png
#   inflating: /content/data_dir/nucleus_images_blue/56.png
#   inflating: /content/data_dir/nucleus_images_blue/55.png
#   inflating: /content/data_dir/nucleus_images_blue/54.png
#   inflating: /content/data_dir/nucleus_images_blue/53.jpg
#   inflating: /content/data_dir/nucleus_images_blue/52.jpg
#   inflating: /content/data_dir/nucleus_images_blue/51.jpg
#   inflating: /content/data_dir/nucleus_images_blue/50.png
#   inflating: /content/data_dir/nucleus_images_blue/5.jpg
#   inflating: /content/data_dir/nucleus_images_blue/49.png

# %%
# import
import numpy as np
import os
import PIL
import PIL.Image
import tensorflow as tf
import tensorflow_datasets as tfds
import pathlib
import matplotlib.pyplot as plt
import random
import cv2
from sklearn.model_selection import train_test_split

# %%
# data_dir
data_dir = "/content/data_dir"
data_dir = pathlib.Path(data_dir)

# %%
# image_count
image_count = len(list(data_dir.glob('*/*.*')))

# %%
# configs
batch_size = 3
img_height = 128
img_width = 128

# %%
# train dataset
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="training",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 340 files belonging to 2 classes.
# Using 272 files for training.

# %%
# validation dataset
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir,
  validation_split=0.2,
  subset="validation",
  seed=123,
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 340 files belonging to 2 classes.
# Using 68 files for validation.

# %%
# class names
class_names = train_ds.class_names

# %%
# serialize data
normalization_layer = tf.keras.layers.experimental.preprocessing.Rescaling(1./255)
normalized_ds = train_ds.map(lambda x, y: (normalization_layer(x), y))
image_batch, labels_batch = next(iter(normalized_ds))

# %%
# performance
AUTOTUNE = tf.data.AUTOTUNE

train_ds = train_ds.cache().prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %%
# imagePaths
imagePaths = []

for k, class_name in enumerate(class_names):
    for f in os.listdir(str(data_dir)+"/"+class_name):
        imagePaths.append([str(data_dir)+"/"+class_name+'/'+f, k])

random.shuffle(imagePaths)

# %%
# data and labels
data = []
labels = []

for imagePath in imagePaths:
    image = cv2.imread(imagePath[0])
    image = cv2.resize(image, (img_width, img_height))
    data.append(image)
    
    label = imagePath[1]
    labels.append(label)

# %%
# scale the raw pixel intensities to the range [0, 1]
data = np.array(data, dtype="float") / 255.0
labels = np.array(labels)

# %%
# partition the data into training and testing splits using 80% of
# the data for training and the remaining 20% for testing
(trainX, testX, trainY, testY) = train_test_split(data, labels, test_size=0.2, random_state=42)

# %%
# create model
model = tf.keras.Sequential([
  tf.keras.layers.experimental.preprocessing.Rescaling(1./255),
  tf.keras.layers.Flatten(),
  tf.keras.layers.Dense(128, activation='relu'),
  tf.keras.layers.Dense(len(class_names))
])

# %%
# compile model
model.compile(
  optimizer='adam',
  loss=tf.losses.SparseCategoricalCrossentropy(from_logits=True),
  metrics=['accuracy'])

# %%
# train model
epochs = 3
model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/3
# 91/91 [==============================] - 9s 80ms/step - loss: 3.0311 - accuracy: 0.7353 - val_loss: 1.0795 - val_accuracy: 0.8235
# Epoch 2/3
# 91/91 [==============================] - 4s 39ms/step - loss: 0.3526 - accuracy: 0.9559 - val_loss: 0.8404 - val_accuracy: 0.8824
# Epoch 3/3
# 91/91 [==============================] - 4s 40ms/step - loss: 0.2736 - accuracy: 0.9632 - val_loss: 1.1149 - val_accuracy: 0.8382

# %%
# Evaluate accuracy
test_loss, test_acc = model.evaluate(testX, testY, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 3/3 - 0s - loss: 0.8265 - accuracy: 0.4795
#
# Test accuracy: 0.4794520437717438

# %%
# Make predictions
probability_model = tf.keras.Sequential([model, 
                                         tf.keras.layers.Softmax()])
predictions = probability_model.predict(testX)

# %%
# helper
def plot_image(i, predictions_array, true_label, img):
  true_label, img = true_label[i], img[i]
  plt.grid(False)
  plt.xticks([])
  plt.yticks([])

  plt.imshow(img, cmap=plt.cm.binary)

  predicted_label = np.argmax(predictions_array)
  if predicted_label == true_label:
    color = 'blue'
  else:
    color = 'red'

  plt.xlabel("{} {:2.0f}% ({})".format(class_names[predicted_label],
                                100*np.max(predictions_array),
                                class_names[true_label]),
                                color=color)

def plot_value_array(i, predictions_array, true_label):
  true_label = true_label[i]
  plt.grid(False)
  plt.xticks(range(len(class_names)))
  plt.yticks([])
  thisplot = plt.bar(range(len(class_names)), predictions_array, color="#777777")
  plt.ylim([0, 1])
  predicted_label = np.argmax(predictions_array)

  thisplot[predicted_label].set_color('red')
  thisplot[true_label].set_color('blue')

# %%
# Verify predictions
# Plot the first X test images, their predicted labels, and the true labels.
# Color correct predictions in blue and incorrect predictions in red.
num_rows = 5
num_cols = 3
num_images = num_rows*num_cols
plt.figure(figsize=(2*2*num_cols, 2*num_rows))
for i in range(num_images):
  plt.subplot(num_rows, 2*num_cols, 2*i+1)
  plot_image(i, predictions[i], testY, testX)
  plt.subplot(num_rows, 2*num_cols, 2*i+2)
  plot_value_array(i, predictions[i], testY)
plt.tight_layout()
plt.show()
